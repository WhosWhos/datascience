# %%
# !pip install sqlalchemy
# !pip install ibm_db_sa
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://gdh90811:hZZAejMpB5ZlSr2a@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb?security=SSL

# %%
# %sql select * from SPACEX
# Out:
#  * ibm_db_sa://gdh90811:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb
# Done.
# [(datetime.date(2010, 6, 4), datetime.time(18, 45), 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  (datetime.date(2010, 12, 8), datetime.time(15, 43), 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1', None, 'barrel of B', '0', 'LEO (ISS)', 'NASA (COTS) NRO'),
#  (datetime.date(2012, 5, 22), datetime.time(7, 44), 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  (datetime.date(2012, 10, 8), datetime.time(0, 35), 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  (datetime.date(2013, 3, 1), datetime.time(15, 10), 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
# ...

# %% [markdown]
# ###  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql select DISTINCT LAUNCH_SITE from SPACEX
# Out:
#  * ibm_db_sa://gdh90811:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb
# Done.
# [('CCAFS LC-40',), ('CCAFS SLC-40',), ('KSC LC-39A',), ('VAFB SLC-4E',)]

# %% [markdown]
# ### Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql select * from SPACEX where launch_site like 'CCA%' limit 5
# Out:
#  * ibm_db_sa://gdh90811:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb
# Done.
# [(datetime.date(2010, 6, 4), datetime.time(18, 45), 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  (datetime.date(2010, 12, 8), datetime.time(15, 43), 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1', None, 'barrel of B', '0', 'LEO (ISS)', 'NASA (COTS) NRO'),
#  (datetime.date(2012, 5, 22), datetime.time(7, 44), 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  (datetime.date(2012, 10, 8), datetime.time(0, 35), 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  (datetime.date(2013, 3, 1), datetime.time(15, 10), 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %% [markdown]
# ### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql select sum(payload_mass__kg_) as sum from SPACEX where customer like 'NASA (CRS)'
# Out:
#  * ibm_db_sa://gdh90811:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb
# Done.
# [(38856,)]

# %% [markdown]
# ### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql select avg(payload_mass__kg_) as Average from SPACEX where booster_version like 'F9 v1.1%'
# Out:
#  * ibm_db_sa://gdh90811:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb
# Done.
# [(2534,)]

# %% [markdown]
# ### List the date when the first succesful landing outcome in ground pad was acheived

# %%
# %sql select min(date) as Date from SPACEX where mission_outcome like 'Success'
# Out:
#  * ibm_db_sa://gdh90811:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb
# Done.
# [(datetime.date(2010, 6, 4),)]

# %% [markdown]
# ### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql select booster_version from SPACEX where (mission_outcome like 'Success') 
AND (payload_mass__kg_ BETWEEN 4000 AND 6000) AND (landing__outcome like 'Success (drone ship)')
# Out:
#   File "<ipython-input-18-c116c294d6bf>", line 2
#     AND (payload_mass__kg_ BETWEEN 4000 AND 6000) AND (landing__outcome like 'Success (drone ship)')
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### List the total number of successful and failure mission outcomes

# %%
# %sql SELECT mission_outcome, count(*) as Count FROM SPACEX GROUP by mission_outcome ORDER BY mission_outcome
# Out:
#  * ibm_db_sa://gdh90811:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb
# Done.
# [('Canadian Space Agency (CSA)', 1),
#  ('Failure (in flight)', 1),
#  ('GPS III-03', 1),
#  ('GTO', 1),
#  ('Iridium Communications GFZ ‚ N', 1),
#  ('LEO', 1),
#  ('LEO (ISS)', 1),
#  ('NASA (CCD)', 1),
#  ('NASA (CCDev)', 1),
#  ('NASA (CCP)', 1),
#  ('NASA (CRS)', 4),
#  ('NASA (CTS)', 1),
#  ('NASA - NOAA - ESA - EUMETSAT', 1),
#  ('Republic of Korea Army', 1),
#  ('SAOCOM 1B', 1),
#  ('SSO', 1),
#  ('Sky Perfect JSAT', 1),
#  ('SpaceX', 13),
#  ('Spacecom', 1),
#  ('Success', 64),
#  ('Success (payload status unclear)', 1),
#  ('U.S. Space Force', 1),
#  ('USSF', 1)]

# %% [markdown]
# ### List the names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
maxm = %sql select max(payload_mass__kg_) from SPACEX
maxv = maxm[0][0]
# %sql select booster_version from SPACEX where 
payload_mass__kg_=(select max(payload_mass__kg_) from SPACEX)
# Out:
#   File "<ipython-input-21-e36d3c93f820>", line 4
#     payload_mass__kg_=(select max(payload_mass__kg_) from SPACEX)
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015

# %%
from SPACEX where DATE like '2015%' AND landing__outcome like 'Failure (drone ship)'
# %sql select MONTHNAME(DATE) as Month, landing__outcome, booster_version, launch_site
# Out:
#   File "<ipython-input-23-0601803776fc>", line 1
#     from SPACEX where DATE like '2015%' AND landing__outcome like 'Failure (drone ship)'
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Rank the count of successful landing_outcomes between the date 2010-06-04 and 2017-03-20 in descending order.

# %%
# %sql select landing__outcome, count(*) as count from SPACEX where Date >= '2010-06-04' AND Date <= '2017-03-20'
GROUP by landing__outcome ORDER BY count Desc
# Out:
#   File "<ipython-input-25-c47e59fc5f61>", line 2
#     GROUP by landing__outcome ORDER BY count Desc
#           ^
# SyntaxError: invalid syntax
